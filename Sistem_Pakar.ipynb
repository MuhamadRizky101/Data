# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhamadRizky101/Data/blob/main/Sistem_Pakar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
penyakit = ['Ulat Grayak','Penggorok Daun','Thrips','Kutu Kebul',' Karat Putih',
            'Karat Hitam','Layu Fusarium','Embun Jelaga',
            'Embun Tepung','Hawar Daun','Virus Kerdil','Busuk Pangkal','Kapang kelabu',
            'Bercak daun','Nematoda Akar','Aphids','Busuk Daun',' Kanker Batang',' Busuk Akar']
gejala = ['Daun Menguning','Daun Mengering','Daun layu dan gugur',
          'Daun cekung dan rapuh','Daun kerdil atau berkerut',
          'Daun menguning terutama daun bagian bawah',
          'Tepi daun berkerut','menggulung ke dalam',
          'Daun tertutupi lapisan hitam seperti jelaga hitam',
          'Lapisan tepung pada permukaan daun',
          'Serangan pada daun bagian bawah/seluruh daun',
          'Adanya bercak-bercak putih pada daun',
          'Bintik kuning pada permukaan atas daun',
          'Bintik coklat atau hitam di permukaan atas daun',
          'Bintik putih pada permukaan bawah daun',
          'Bintik klorosis di permukaan bawah daun',
          'Terdapat koloni putih dibagian bawah daun',
          'Adanya alur berliku bekas kotoran berwarna putih pada daun',
          'Tersisa hanya tulang daun pada tanaman',' Bercak coklat pada daun',
          'Bercak coklat pada pinggir daun',
          'Bercak-bercak kehitaman pada makhota bunga',
          'Epidermis atau bagian atas daun rusak/transparan',
          'Tidak membentuk tunas samping',' Hama memakan tunas dan bunga',
          'Berbunga lebih awal dari tanaman sehat',' Bunga bergaris-garis',' Warna bunga yang pucat',
          'Tangkai bunga terlihat pucat',' Gagal berbunga',' Pangkal batang membusuk',
          'Tanaman membusuk atau mati',' Tanaman kerdil',' Tanaman layu',
          'Pertumbuhan bagisan tanaman terhambat atau mati',' Akar berwarna coklat sampai hitam',
          'Daun muda halus, tipis, dan lemas',' Bunga rusak tidak beraturan',' Batang Terkulai/Layu',' Akar Mengkerut',
          'Terbentuk Bintil Bintil Akar',' Daun Kemerah merah an',' Ujung daun rusak menjadi bergerigi',
          'Tanaman terlihat putih',' Perkembangan kuncup terhambat',' Tangkai daun kecil dan lemah',
          'Warna daun berubah menjadi gelap',' Permukaan daun mengkilap',' Perakaran lemah',' Terdapat lubang tidak beraturan',
          'Batang terdapat warna coklat melingkar',' Nekrosis pada daun muda',' Nekrosis pada daun tua']
kasus = ['K01','K02','K03','K04','K05','K06','K07','K08','K09','K10','K11','K12','K13','K14','K15','K16','K17','K18','K19','K20','K21','K22','K23','K24','K25','K26','K27','K28','K29','K30','K31','K32','K33','K34','K35','K36','K37','K38','K39']
basis_kasus = [
    ['K01','Ulat Grayak','Daun layu dan gugur'],
    ['K01','Ulat Grayak','Tersisa hanya tulang daun pada tanaman'],
    ['K01','Ulat Grayak','Epidermis atau bagian atas daun rusak/transparan'],
    ['K01','Ulat Grayak','Hama memakan tunas dan bunga'],
    ['K02','Penggorok Daun','Daun Menguning'],
    ['K02','Penggorok Daun','Daun Mengering'],
    ['K02','Penggorok Daun','Daun layu dan gugur'],
    ['K02','Penggorok Daun','Adanya alur berliku bekas kotoran berwarna putih pada daun'],
    ['K03','Thrips','Daun kerdil atau berkerut'],
    ['K03','Thrips','Adanya bercak-bercak daun bagian bawah/seluruh'],
    ['K03','Thrips','Bercak-bercak kehitaman pada mahkota bunga'],
    ['K03','Thrips','bunga bergaris-garis'],
    ['K04','Kutu Kebul','Terdapat koloni putih dibagian bawah daun'],
    ['K04','Kutu Kebul','Bercak coklat pada pinggir daun '],
    ['K04','Kutu Kebul','Tangkai bunga yang pucat'],
    ['K04','Kutu Kebul','Tanaman membusuk atau mati'],
    ['K04','Kutu Kebul','Pertumbuhan bagian atas tanaman terhambat atau mati'],
    ['K05','Karat Putih','Serangan pada daun bagian bawah/seluruh daun'],
    ['K05','Karat Putih','Bintik kuning pada permukaan atas daun'],
    ['K05','Karat Putih','Bintik putih padapermukaan bawah daun'],
    ['K06','Karat Hitam','Serangan pada daun bagian bawah/seluruh daun'],
    ['K06','Karat Hitam','Bintik coklat atau hitam dipermukaan atas daun'],
    ['K06','Karat Hitam','Terdapat koloni putih dibagian bawah daun'],
    ['K07','Layu Furasium','Daun Menguning'],
    ['K07','Layu Furasium','Daun Mengering'],
    ['K07','Layu Furasium','Tanaman membusuk atau mati'],
    ['K07','Layu Furasium','Tanaman layu'],
    ['K07','Layu Furasium','Pertumbuhan bagian atas tanaman terhambat atau mati'],
    ['K08','Embun Jelaga','Daun Mengering'],
    ['K08','Embun Jelaga','Daun tertutupi lapisan hitam seperti jelaga hitam'],
    ['K08','Embun Jelaga','Serangan pada daun bagian bawah/seluruh daun'],
    ['K09','Embun Tepung','Daun Mengering'],
    ['K09','Embun Tepung','Daun cekung dan rapuh'],
    ['K09','Embun Tepung','Lapisan tepung pada permukaan daun'],
    ['K10','Hawar Daun','Daun Mengering'],
    ['K10','Hawar Daun','Daun cekung dan rapuh'],
    ['K10','Hawar Daun','Bercak coklat pada pinggir daun'],
    ['K11','Virus Kerdil','Daun kerdil atau berkerut'],
    ['K11','Virus Kerdil','Tidak membentuk tunas samping'],
    ['K11','Virus Kerdil','Berbunga lebih awal dari tanaman sehat'],
    ['K11','Virus Kerdil','Warna bunga terlihat pucat'],
    ['K12','Busuk Pangkal','Daun kerdil atau berkerut'],
    ['K12','Busuk Pangkal','Pangkal batang membusuk'],
    ['K12','Busuk Pangkal','Tanaman layu'],
    ['K12','Busuk Pangkal','Akar berwarna coklat sampai hitam dan mengkerut'],
    ['K13','Kapang Kelabu','Daun Menguning'],
    ['K13','Kapang Kelabu','Daun menguning terutama pada bagian bawah'],
    ['K13','Kapang Kelabu','Serangan pada daun bagian bawah/seluruh daun'],
    ['K13','Kapang Kelabu','Gagal berbunga'],
    ['K14','Bercak Daun','Daun Menguning'],
    ['K14','Bercak Daun','Daun Mengering'],
    ['K14','Bercak Daun','Serangan pada daun bagian bawah/seluruh daun'],
    ['K14','Bercak Daun','Tersisa hanya tulang daun pada tanaman'],
    ['K15','Nematoda Akar','Bintik coklat atau hitam di permukaan atas daun'],
    ['K15','Nematoda Akar','Akar Mengkerut'],
    ['K15','Nematoda Akar','Ujung daun rusak menjadi bergerigi'],
    ['K15','Nematoda Akar','Perakaran lemah'],
    ['K16','Aphids','Bunga bergaris-garis'],
    ['K16','Aphids','Bunga rusak tidak beraturan'],
    ['K16','Aphids','Terbentuk Bintil Bintil Akar'],
    ['K16','Aphids','Tangkai daun kecil dan lemah'],
    ['K16','Aphids','Terdapat lubang tidak beraturan'],
    ['K17','Busuk Daun','Bercak coklat pada daun'],
    ['K17','Busuk Daun','Hama memakan tunas dan bunga'],
    ['K17','Busuk Daun','Daun muda halus, tipis, dan lemas'],
    ['K17','Busuk Daun','Batang Terkulai/Layu'],
    ['K17','Busuk Daun','Daun Kemerah merah an'],
    ['K17','Busuk Daun','Perkembangan kuncup terhambat'],
    ['K17','Busuk Daun','batang terdapat warna coklat melingkar'],
    ['K18','Kanker batang','Bercak coklat pada daun'],
    ['K18','Kanker batang','Terbentuk Bintil Bintil Akar'],
    ['K18','Kanker batang','Tanaman terlihat putih'],
    ['K18','Kanker batang','Permukaan daun mengkilap'],
    ['K18','Kanker batang','Nekrosis pada daun muda'],
    ['K18','Kanker batang','Nekrosis pada daun tua'],
    ['K19','Busuk Akar','Daun cekung dan rapuh'],
    ['K19','Busuk Akar','Bunga rusak tidak beraturan'],
    ['K19','Busuk Akar','Akar Mengkerut'],
    ['K19','Busuk Akar','Warna daun berubah menjadi gelap'],
    ['K19','Busuk Akar','Terdapat lubang tidak beraturan'],
    ['K20','Ulat Grayak','Daun layu dan gugur'],
    ['K20','Ulat Grayak','Tersisa hanya tulang daun pada tanaman'],
    ['K20','Ulat Grayak','Epidermis atau bagian atas daun rusak/transparan'],
    ['K21','Ulat Grayak','Tersisa hanya tulang daun pada tanaman'],
    ['K21','Ulat Grayak','Bercak-bercak kehitaman pada mahkota bunga'],
    ['K21','Ulat Grayak','Hama memakan tunas dan bunga'],
    ['K22','Penggorok Daun','Daun Menguning'],
    ['K22','Penggorok Daun','Daun layu dan gugur'],
    ['K22','Penggorok Daun','Adanya alur berliku bekas kotoran berwarna putih pada daun'],
    ['K23','Penggorok Daun','Daun Mengering'],
    ['K23','Penggorok Daun','Daun layu dan gugur'],
    ['K23','Penggorok Daun','Adanya alur berliku bekas kotoran berwarna putih pada daun'],
    ['K24','Thrips','Tepi daun berkerut, menggulung ke dalam'],
    ['K24','Thrips','Adanya bercak-bercak putih pada daun'],
    ['K24','Thrips','Bercak-bercak kehitaman pada mahkota bunga'],
    ['K25','Thrips','Daun Mengering'],
    ['K25','Thrips','Tepi daun berkerut, menggulung ke dalam'],
    ['K25','Thrips','Adanya bercak-bercak putih pada daun'],
    ['K25','Thrips','Bercak-bercak kehitaman pada mahkota bunga'],
    ['K26','Kutu Kebul','Tangkai bunga yang pucat'],
    ['K26','Kutu Kebul','Tanaman membusuk atau mati'],
    ['K26','Kutu Kebul','Pertumbuhan bagian atas tanaman terhambat atau mati'],
    ['K27','Layu Fusarium','Daun Menguning'],
    ['K27','Layu Fusarium','Daun Mengering'],
    ['K27','Layu Fusarium','Tanaman layu'],
    ['K28','Layu Fusarium','Tanaman kerdil'],
    ['K28','Layu Fusarium','Tanaman layu'],
    ['K28','Layu Fusarium','Pertumbuhan bagian atas tanaman terhambat atau mati'],
    ['K29','Hawar Daun','Daun menguning terutama pada bagian bawah'],
    ['K29','Hawar Daun','Berbunga lebih awal dari tanaman sehat'],
    ['K29','Hawar Daun','Warna bunga yang pucat'],
    ['K30','Virus Kerdil','Daun menguning terutama pada bagian bawah'],
    ['K30','Virus Kerdil','Pangkal batang membusuk'],
    ['K30','Virus Kerdil','Tanaman layu'],
    ['K31','Virus Kerdil','Pangkal batang membusuk'],
    ['K31','Virus Kerdil','Tanaman layu'],
    ['K31','Virus Kerdil','Akar berwarna coklat sampai hitam dan mengkerut'],
    ['K32','Bercak Daun','Daun Menguning'],
    ['K32','Bercak Daun','Daun Mengering'],
    ['K32','Bercak Daun','Bercak coklat pada daun'],
    ['K33','Nematoda Akar','Daun layu dan gugur'],
    ['K33','Nematoda Akar','Bintik coklat atau hitam di permukaan atas daun'],
    ['K33','Nematoda Akar','Ujung daun rusak menjadi bergerigi'],
    ['K34','Nematoda Akar','bintik coklat atau hitam di permukaan atas daun'],
    ['K34','Nematoda Akar','Tidak membentuk tunas samping'],
    ['K34','Nematoda Akar','Akar Mengkerut'],
    ['K34','Nematoda Akar','Perakaran lemah'],
    ['K35','Aphids','Berbunga lebih awal dari tanaman sehat'],
    ['K35','Aphids','bunga bergaris-garis'],
    ['K35','Aphids','Tangkai daun kecil dan lemah'],
    ['K35','Aphids','Terdapat lubang tidak beraturan'],
    ['K36','Busuk Daun','Adanya bercak-bercak putih pada daun'],
    ['K36','Busuk Daun','Bercak coklat pada daun'],
    ['K36','Busuk Daun','Hama memakan tunas dan bunga'],
    ['K36','Busuk Daun','Warna bunga yang pucat'],
    ['K36','Busuk Daun','Perkembangan kuncup terhambat'],
    ['K36','Busuk Daun','Batang terdapat warna coklat melingkar'],
    ['K37','Kanker Batang','Bercak coklat pada daun'],
    ['K37','Kanker Batang','Warna bunga yang pucat'],
    ['K37','Kanker Batang','Tanaman terlihat putih'],
    ['K37','Kanker Batang','Permukaan daun mengkilap'],
    ['K38','Kanker Batang','Daun Mengering'],
    ['K38','Kanker Batang','Bunga bergaris-garis'],
    ['K38','Kanker Batang','Batang Terkulai/Layu'],
    ['K38','Kanker Batang','Permukaan daun mengkilap'],
    ['K38','Kanker Batang','Nekrosis pada daun muda'],
    ['K39','Busuk Akar','Daun cekung dan rapuh'],
    ['K39','Busuk Akar','Terdapat koloni putih dibagian bawah daun'],
    ['K39','Busuk Akar','Bunga rusak tidak beraturan'],
    ['K39','Busuk Akar','Perkembangan kuncup terhambat'],
    ['K39','Busuk Akar','Warna daun berubah menjadi gelap']
]
gejala_dipilih = []
for i in range(len(gejala)):
    jawab = input('Apakah Mengalami '+gejala[i]+'(Y/T)?')
    if jawab.upper() == 'Y':
        gejala_dipilih.append(True)
    else:
        gejala_dipilih.append(False)
print('Gejala Dipilih',gejala_dipilih)
jml_gejala_dipilih = 0
jml_gejala_kasus = 0
jml_gejala_cocok = 0
nilai_hasil = []
penyakit_kasus = []
for i in range(len(kasus)):
    jml_gejala_dipilih = 0
    jml_gejala_kasus = 0
    jml_gejala_cocok = 0
    penyakit_kasus.append('')
    for j in range(len(gejala)):
        if (gejala_dipilih[j] == True):
            jml_gejala_kasus = 0
            jml_gejala_dipilih = jml_gejala_dipilih + 1
            for k in range(len(basis_kasus)):
                if (basis_kasus [k][0] == kasus [i]):
                    penyakit_kasus [i] = basis_kasus[k][1]
                    jml_gejala_kasus = jml_gejala_kasus + 1
                    if (basis_kasus [k] [2] == gejala[j]):
                        jml_gejala_cocok = jml_gejala_cocok + 1
    print('===', kasus[i], '===')
    print('Penyakit:', penyakit_kasus[i])
    print('jml Gejala Dipilih:', jml_gejala_dipilih)
    print('jml Gejala di Kasus:', jml_gejala_kasus)
    print('jml yang cocok:', jml_gejala_cocok)
    pembagi = max(jml_gejala_dipilih, jml_gejala_kasus)
    print('Pembagi: MAX(',jml_gejala_dipilih, ',',jml_gejala_kasus,')=', pembagi)
    if (pembagi == 0):
        hasil = 0
    else:
        hasil = jml_gejala_cocok / pembagi
    print('hasil', jml_gejala_cocok, '/', pembagi, '=', hasil)
    nilai_hasil.append(hasil)
print('')
kasusranking = []
penyakitranking = []
hasilranking = []
for i in range(len(kasus)):
    kasusranking.append(kasus[i])
    penyakitranking.append(penyakit_kasus[i])
    hasilranking.append(nilai_hasil[i])
for i in range(len(kasus)):
    for j in range(len(kasus)):
        if j > i :
            if hasilranking[j] > hasilranking[i]:
                tmphasil = hasilranking[i]
                tmpkasus = kasusranking[i]
                tmppenyakit = penyakitranking[i]
                hasilranking[i] = hasilranking[j]
                kasusranking[i] = kasusranking[j]
                penyakitranking[i] = penyakitranking[j]
                hasilranking[j] = tmphasil
                kasusranking[j] = tmpkasus
                penyakitranking[j] = tmppenyakit
                hasil_diagnosa = [penyakitranking[:1]]
print('Ranking Kasus:',kasusranking[:5])
print('Ranking Penyakit:',penyakitranking[:5])
print('Ranking Hasil:',hasilranking[:5])
print('Hasil Diagnosa Akhir:',hasil_diagnosa)
# Out:
# Apakah Mengalami Daun Menguning(Y/T)?T
# Apakah Mengalami Daun Mengering(Y/T)?T
# Apakah Mengalami Daun layu dan gugur(Y/T)?Y
# Apakah Mengalami Daun cekung dan rapuh(Y/T)?T
# Apakah Mengalami Daun kerdil atau berkerut(Y/T)?T
# Apakah Mengalami Daun menguning terutama daun bagian bawah(Y/T)?Y
# Apakah Mengalami Tepi daun berkerut(Y/T)?T
# Apakah Mengalami menggulung ke dalam(Y/T)?T
# Apakah Mengalami Daun tertutupi lapisan hitam seperti jelaga hitam(Y/T)?T
# Apakah Mengalami Lapisan tepung pada permukaan daun(Y/T)?Y
# Apakah Mengalami Serangan pada daun bagian bawah/seluruh daun(Y/T)?Y
# Apakah Mengalami Adanya bercak-bercak putih pada daun(Y/T)?T
# Apakah Mengalami Bintik kuning pada permukaan atas daun(Y/T)?T
# Apakah Mengalami Bintik coklat atau hitam di permukaan atas daun(Y/T)?T
# Apakah Mengalami Bintik putih pada permukaan bawah daun(Y/T)?T
# Apakah Mengalami Bintik klorosis di permukaan bawah daun(Y/T)?T
# Apakah Mengalami Terdapat koloni putih dibagian bawah daun(Y/T)?T
# ...

# %%
TT
